-- %%
CREATE OR REPLACE FUNCTION kraft_udfs.domain_1.hh_type_ind(HOUSEHOLD_TYPE_IND INT)
RETURNS STRING
LANGUAGE SQL
RETURN
    CASE 
        WHEN HOUSEHOLD_TYPE_IND = 0 THEN 'Family Household'
        ELSE 'Single/Non-Family Household'
    END
