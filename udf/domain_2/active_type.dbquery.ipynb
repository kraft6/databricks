-- %%
CREATE OR REPLACE FUNCTION kraft_udfs.domain_2.active_type(ACTV_MEM_RLTN_IND_CNT INT)
RETURNS STRING
LANGUAGE SQL
RETURN
    CASE 
        WHEN ACTV_MEM_RLTN_IND_CNT = 0 THEN 'Inactive Relationship'
        ELSE 'Active Relationship'
    END
